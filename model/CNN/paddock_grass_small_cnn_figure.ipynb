# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import rasterio

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import KFold

import torch
from torch.utils.data import Dataset, DataLoader, Subset
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchsummary import summary
from torch.utils.data import DataLoader, random_split

# %%
class SmallCNN5(nn.Module):
    def __init__(self, input_channels=10, num_classes=2, image_shape=(50, 50)):
        super(SmallCNN5, self).__init__()

        H, W = image_shape

        # First CNN Layer
        self.conv1 = nn.Conv2d(input_channels, 32, kernel_size=3, padding=1)
        self.bn1 = nn.LayerNorm([32, H, W])
        self.act1 = nn.GELU()
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)  # Downsample by 2

        # Depthwise Separable Convolution
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bn2 = nn.LayerNorm([64, H // 2, W // 2])
        self.act2 = nn.GELU()
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.pointwise = nn.Conv2d(64, 64, kernel_size=1)

        self.gap = nn.AdaptiveAvgPool2d((4, 4))

        # Fully Connected Layer
        self.cls_head = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 4 * 4, 64),
            nn.RMSNorm(64),
            nn.GELU(),
            nn.Linear(64, num_classes)
        )

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.act1(x)
        x = self.pool1(x)

        x = self.conv2(x)
        x = self.bn2(x)
        x = self.act2(x)
        x = self.pool2(x)

        x = self.pointwise(x)
        x = self.gap(x)
        x = self.cls_head(x)

        return x


super_model = SmallCNN5(num_classes=2).to('cuda')
print(f"Total parameters: {sum(p.numel() for p in super_model.parameters() if p.requires_grad)}")
summary(super_model, (10,50,50))
# Out:
# Total parameters: 331362
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 50, 50]           2,912
#          LayerNorm-2           [-1, 32, 50, 50]         160,000
#               GELU-3           [-1, 32, 50, 50]               0
#          MaxPool2d-4           [-1, 32, 25, 25]               0
#             Conv2d-5           [-1, 64, 25, 25]          18,496
#          LayerNorm-6           [-1, 64, 25, 25]          80,000
#               GELU-7           [-1, 64, 25, 25]               0
#          MaxPool2d-8           [-1, 64, 12, 12]               0
#             Conv2d-9           [-1, 64, 12, 12]           4,160
# AdaptiveAvgPool2d-10             [-1, 64, 4, 4]               0
#           Flatten-11                 [-1, 1024]               0
#            Linear-12                   [-1, 64]          65,600
#           RMSNorm-13                   [-1, 64]              64
#              GELU-14                   [-1, 64]               0
#            Linear-15                    [-1, 2]             130
# ================================================================
# Total params: 331,362
# Trainable params: 331,362
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.10
# Forward/backward pass size (MB): 3.06
# Params size (MB): 1.26
# Estimated Total Size (MB): 4.42
# ----------------------------------------------------------------

# %%
class SmallCNN4(nn.Module):
    def __init__(self, input_channels=10, num_classes=2):
        super(SmallCNN4, self).__init__()

        # First CNN Layer
        self.conv1 = nn.Conv2d(input_channels, 32, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(32)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)  # Downsample by 2

        # Depthwise Separable Convolution
        self.depthwise = nn.Conv2d(32, 32, kernel_size=3, padding=1, groups=32)
        self.pointwise = nn.Conv2d(32, 64, kernel_size=1)

        # Global Average Pooling to (2, 2)
        self.gap = nn.AdaptiveAvgPool2d((4, 4))

        # Fully Connected Layer
        self.fc = nn.Linear(64 * 4 * 4, num_classes)  # 64 channels with spatial size (2, 2)

    def forward(self, x):
        # First CNN Layer
        x = F.relu(self.bn1(self.conv1(x)))
        x = self.pool1(x)

        # Depthwise Separable Convolution
        x = F.relu(self.pointwise(self.depthwise(x)))

        # Global Average Pooling
        x = self.gap(x).view(x.size(0), -1)

        # Fully Connected Layer
        x = self.fc(x)

        return x
    
    
super_model = SmallCNN4(num_classes=2).to('cuda')
print(f"Total parameters: {sum(p.numel() for p in super_model.parameters() if p.requires_grad)}")
summary(super_model, (10,50,50))
# Out:
# Total parameters: 7458
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 50, 50]           2,912
#        BatchNorm2d-2           [-1, 32, 50, 50]              64
#          MaxPool2d-3           [-1, 32, 25, 25]               0
#             Conv2d-4           [-1, 32, 25, 25]             320
#             Conv2d-5           [-1, 64, 25, 25]           2,112
#  AdaptiveAvgPool2d-6             [-1, 64, 4, 4]               0
#             Linear-7                    [-1, 2]           2,050
# ================================================================
# Total params: 7,458
# Trainable params: 7,458
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.10
# Forward/backward pass size (MB): 1.84
# Params size (MB): 0.03
# Estimated Total Size (MB): 1.96
# ----------------------------------------------------------------

# %%
class GeoTIFFDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        """
        Args:
            root_dir (string): Directory with all the images, organized in subfolders per class.
            transform (callable, optional): Optional transform to be applied on a sample.
        """
        self.root_dir = root_dir
        self.transform = transform
        # self.classes = sorted(os.listdir(root_dir))
        self.classes = ['grass', 'legume']
        self.class_to_idx = {cls_name: idx for idx, cls_name in enumerate(self.classes)}
        self.image_paths = []
        self.labels = []
        
        # for cls in self.classes:
        #     cls_folder = os.path.join(root_dir, cls)
        #     for file in os.listdir(cls_folder):
        #         if file.endswith('.tif') or file.endswith('.tiff'):
        #             self.image_paths.append(os.path.join(cls_folder, file))
        #             self.labels.append(self.class_to_idx[cls])

        for file in os.listdir(root_dir):
            if file.endswith('.tif') or file.endswith('.tiff'):
                self.image_paths.append(os.path.join(root_dir, file))
                self.labels.append(self.class_to_idx[file.split('_')[1]])

    def __len__(self):
        return len(self.image_paths)
    
    def compute_indices(self, bands):
        """
        Compute NDVI, SAVI, VARI, EXG, NDRE indices.
        Args:
            bands (numpy array): Array of shape (6, H, W)
        Returns:
            indices (numpy array): Array of shape (5, H, W)
        """
        # Assuming band order: 0=Blue, 1=Green, 2=Red, 3=NIR, 4=RE, 5=SWIR
        blue = bands[0].astype(float)
        green = bands[1].astype(float)
        red = bands[2].astype(float)
        re = bands[3].astype(float)
        nir = bands[4].astype(float)
        # swir = bands[5].astype(float)  # Not used in indices here
        
        # NDVI
        ndvi = (nir - red) / (nir + red + 1e-6)
        
        # SAVI (L=0.5)
        L = 0.5
        savi = ((nir - red) / (nir + red + L)) * (1 + L)
        
        # VARI
        vari = (green - red) / (green + red - blue + 1e-6)
        
        # EXG
        exg = 2 * green - red - blue
        
        # NDRE
        ndre = (nir - re) / (nir + re + 1e-6)
        
        # Stack indices
        indices = np.stack([ndvi, savi, vari, exg, ndre], axis=0)
        
        return indices
    
    def normalize(self, data):
        """
        Normalize each channel to have zero mean and unit variance.
        Args:
            data (numpy array): Array of shape (10, H, W)
        Returns:
            normalized_data (torch.Tensor): Normalized tensor
        """
        # Flatten to (C, H*W) for mean/std computation
        C, H, W = data.shape
        data_reshaped = data.reshape(C, -1)
        
        mean = data_reshaped.mean(axis=1, keepdims=True)
        std = data_reshaped.std(axis=1, keepdims=True) + 1e-6  # Prevent division by zero
        
        normalized = (data - mean.reshape(C, 1, 1)) / std.reshape(C, 1, 1)
        return normalized
    
    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        label = self.labels[idx]
        
        with rasterio.open(img_path) as src:
            # bands = src.read()  # Shape: (6, H, W)
            bands = src.read(list(range(1, src.count)))
        
        indices = self.compute_indices(bands)  # Shape: (10, H, W)
        
        # Stack original bands with indices
        data = np.concatenate([bands, indices], axis=0)  # Shape: (10, H, W)
        
        # Normalize
        data = self.normalize(data)
        
        # Convert to float32
        data = data.astype(np.float32)
        
        # Apply transformations if any (e.g., data augmentation)
        if self.transform:
            data = self.transform(data)
        
        # Convert to torch tensor
        tensor = torch.from_numpy(data)
        
        return tensor, label

# %%
def train_and_validate_with_test(
    model, 
    train_loader, 
    val_loader, 
    test_loader,
    pad_test_loader,
    criterion, 
    optimizer, 
    scheduler=None, 
    num_epochs=50, 
    patience=10, 
    device='cuda'
):
    best_model_weights = None
    best_val_loss = float('inf')
    train_loss_history, val_loss_history = [], []
    early_stopping_counter = 0

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * inputs.size(0)

        train_loss /= len(train_loader.dataset)
        train_loss_history.append(train_loss)

        # Validation phase
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * inputs.size(0)

        val_loss /= len(val_loader.dataset)
        val_loss_history.append(val_loss)

        # Check early stopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_weights = model.state_dict()
            early_stopping_counter = 0
        else:
            early_stopping_counter += 1
            if early_stopping_counter >= patience:
                print(f"Early stopping triggered at epoch {epoch + 1}")
                break

        # Step the scheduler
        if scheduler:
            scheduler.step(val_loss)

        print(f"Epoch {epoch + 1}/{num_epochs} - Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

    # Load best model weights
    model.load_state_dict(best_model_weights)

    # Testing phase
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            all_preds.append(preds.cpu().numpy())
            all_labels.append(labels.cpu().numpy())

    all_preds = np.concatenate(all_preds)
    all_labels = np.concatenate(all_labels)
    cm = confusion_matrix(all_labels, all_preds)

    with torch.no_grad():
        pad_all_preds, pad_all_labels = [], []
        for inputs, labels in pad_test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            pad_all_preds.append(preds.cpu().numpy())
            pad_all_labels.append(labels.cpu().numpy())

    pad_all_preds = np.concatenate(pad_all_preds)
    pad_all_labels = np.concatenate(pad_all_labels)
    pad_cm = confusion_matrix(pad_all_labels, pad_all_preds)

    return train_loss_history, val_loss_history, cm, pad_cm, best_model_weights

# %%
# Example: No additional transformations 50 pixel
train_transform = None
test_transform = None
# Paths to training and testing folders
data_root = './data/patch_paddock/'

eval_data = []

for pad_data in os.listdir(data_root):
    if not os.path.isdir(os.path.join(data_root, pad_data)):
        continue

    model_save_dir = os.path.join('./saved_models/', pad_data + '_patch50/')
    train_dir = os.path.join(data_root, pad_data, 'patch_50', 'train')
    test_dir = os.path.join(data_root, pad_data, 'patch_50', 'test')
    pad_test_dir = os.path.join(data_root, pad_data, 'patch_50', 'pad_test')

    # Create dataset instances
    train_dataset = GeoTIFFDataset(root_dir=train_dir, transform=train_transform)
    test_dataset = GeoTIFFDataset(root_dir=test_dir, transform=test_transform)
    pad_test_dataset = GeoTIFFDataset(root_dir=pad_test_dir, transform=test_transform)
    num_classes = len(train_dataset.classes)  # Number of classes based on dataset

    if not os.path.exists(model_save_dir):
        os.makedirs(model_save_dir)

    # Step 3: Initialize KFold
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Step 5: Perform Cross-Validation
    fold_results = []
    for fold, (train_idx, val_idx) in enumerate(kf.split(train_dataset)):
        print(f"Starting Fold {fold + 1}")
        
        train_data = Subset(train_dataset, train_idx)
        val_data = Subset(train_dataset, val_idx)

        # Create DataLoaders
        train_loader = DataLoader(train_data, batch_size=32, shuffle=True, num_workers=8)
        val_loader = DataLoader(val_data, batch_size=32, shuffle=False, num_workers=8)
        test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=8)
        pad_test_loader = DataLoader(pad_test_dataset, batch_size=32, shuffle=False, num_workers=8)

        # Initialize model, criterion, optimizer, and scheduler
        model = SmallCNN4(input_channels=10, num_classes=2).to(device)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.AdamW(model.parameters(), lr=1e-3)
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=3, factor=0.5)

        # Train and validate the model
        train_loss, val_loss, cm, pad_cm, best_model_weights = train_and_validate_with_test(
            model=model,
            train_loader=train_loader,
            val_loader=val_loader,
            test_loader=test_loader,
            pad_test_loader=pad_test_loader,
            criterion=criterion,
            optimizer=optimizer,
            scheduler=scheduler,
            num_epochs=100,
            patience=15,
            device=device
        )

        torch.save(best_model_weights, os.path.join(model_save_dir, f'smallcnn4_fold{fold+1}_pad9_patch50.pth'))

        # Save results for this fold
        fold_results.append({
            'fold': fold + 1,
            'train_loss': train_loss,
            'val_loss': val_loss,
            'confusion_matrix': cm,
            'pad_confusion_matrix': pad_cm
        })

    plt.rcParams.update({'font.size': 12})
    for result in fold_results:
        print(f"Fold {result['fold']}:")
        print("Confusion Matrix:")
        print(result['confusion_matrix'])
        plt.plot(result['train_loss'], label=f"Fold {result['fold']} Train Loss")
        plt.plot(result['val_loss'], label=f"Fold {result['fold']} Val Loss", linestyle='dashed')
    plt.legend()
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title(f"{pad_data} Training and Validation Loss")

    plt.show()

    # plt.rcParams.update({'font.size': 16})

    for result in fold_results:
        cm = result['confusion_matrix']
        pad_cm = result['pad_confusion_matrix']

        norm_cm = cm / cm.sum(axis=1, keepdims=True)
        norm_pad_cm = pad_cm / pad_cm.sum(axis=1, keepdims=True)

        fig, axes = plt.subplots(2, 2, figsize=(12, 10))

        disp = ConfusionMatrixDisplay(cm, display_labels=train_dataset.classes)
        disp.plot(cmap='Blues', xticks_rotation='horizontal', ax=axes[0, 0])
        axes[0, 0].set_title(f'Prediction number')
        axes[0, 0].set_ylabel('True label', rotation='vertical')

        disp = ConfusionMatrixDisplay(norm_cm, display_labels=train_dataset.classes)
        disp.plot(cmap='Blues', xticks_rotation='horizontal', values_format=".2f", ax=axes[0, 1])
        axes[0, 1].set_title(f'Prediction percentage')
        axes[0, 1].set_ylabel('True label', rotation='vertical')

        disp = ConfusionMatrixDisplay(pad_cm, display_labels=train_dataset.classes)
        disp.plot(cmap='Blues', xticks_rotation='horizontal', ax=axes[1, 0])
        axes[1, 0].set_title(f'Prediction number (Paddock)')
        axes[1, 0].set_ylabel('True label', rotation='vertical')

        disp = ConfusionMatrixDisplay(norm_pad_cm, display_labels=train_dataset.classes)
        disp.plot(cmap='Blues', xticks_rotation='horizontal', values_format=".2f", ax=axes[1, 1])
        axes[1, 1].set_title(f'Prediction percentage (Paddock)')
        axes[1, 1].set_ylabel('True label', rotation='vertical')

        fig.suptitle(f'{pad_data} Fold {result["fold"]}', fontsize=18, y=0.995)
        plt.tight_layout()
        plt.show()

        grass_precision = cm[0,0] / (cm[0,0] + cm[1,0] + 1e-6)
        grass_recall = cm[0,0] / (cm[0,0] + cm[0,1] + 1e-6)
        grass_sensitivity = grass_recall
        grass_specificity = cm[1,1] / (cm[1,1] + cm[1,0] + 1e-6)
        grass_f1 = 2 * (grass_precision * grass_recall) / (grass_precision + grass_recall + 1e-6)

        legume_precision = cm[1,1] / (cm[1,1] + cm[0,1] + 1e-6)
        legume_recall = cm[1,1] / (cm[1,1] + cm[1,0] + 1e-6)
        legume_sensitivity = legume_recall
        legume_specificity = cm[0,0] / (cm[0,0] + cm[0,1] + 1e-6)
        legume_f1 = 2 * (legume_precision * legume_recall) / (legume_precision + legume_recall + 1e-6)

        avg_precision = (grass_precision + legume_precision) / 2
        avg_sensitivity = (grass_sensitivity + legume_sensitivity) / 2
        avg_specificity = (grass_specificity + legume_specificity) / 2
        avg_f1 = (grass_f1 + legume_f1) / 2

        # print(f"Fold {result['fold']} - Grass: Precision: {grass_precision:.4f}, Recall: {grass_recall:.4f}, Specificity: {grass_specificity:.4f}, F1 Score: {grass_f1:.4f}")
        # print(f"Fold {result['fold']} - Legume: Precision: {legume_precision:.4f}, Recall: {legume_recall:.4f}, Specificity: {legume_specificity:.4f}, F1 Score: {legume_f1:.4f}")
        # print(f"Fold {result['fold']} - Average: Precision: {avg_precision:.4f}, Recall: {avg_sensitivity:.4f}, Specificity: {avg_specificity:.4f}, F1 Score: {avg_f1:.4f}")

        pad_grass_precision = pad_cm[0,0] / (pad_cm[0,0] + pad_cm[1,0] + 1e-6)
        pad_grass_recall = pad_cm[0,0] / (pad_cm[0,0] + pad_cm[0,1] + 1e-6)
        pad_grass_sensitivity = pad_grass_recall
        pad_grass_specificity = pad_cm[1,1] / (pad_cm[1,1] + pad_cm[1,0] + 1e-6)
        pad_grass_f1 = 2 * (pad_grass_precision * pad_grass_recall) / (pad_grass_precision + pad_grass_recall + 1e-6)

        pad_legume_precision = pad_cm[1,1] / (pad_cm[1,1] + pad_cm[0,1] + 1e-6)
        pad_legume_recall = pad_cm[1,1] / (pad_cm[1,1] + pad_cm[1,0] + 1e-6)
        pad_legume_sensitivity = pad_legume_recall
        pad_legume_specificity = pad_cm[0,0] / (pad_cm[0,0] + pad_cm[0,1] + 1e-6)
        pad_legume_f1 = 2 * (pad_legume_precision * pad_legume_recall) / (pad_legume_precision + pad_legume_recall + 1e-6)

        pad_avg_precision = (pad_grass_precision + pad_legume_precision) / 2
        pad_avg_sensitivity = (pad_grass_sensitivity + pad_legume_sensitivity) / 2
        pad_avg_specificity = (pad_grass_specificity + pad_legume_specificity) / 2
        pad_avg_f1 = (pad_grass_f1 + pad_legume_f1) / 2

        # print(f"Fold {result['fold']} ({pad_data}) - Grass: Precision: {pad_grass_precision:.4f}, Recall: {pad_grass_recall:.4f}, Specificity: {pad_grass_specificity:.4f}, F1 Score: {pad_grass_f1:.4f}")
        # print(f"Fold {result['fold']} ({pad_data}) - Legume: Precision: {pad_legume_precision:.4f}, Recall: {pad_legume_recall:.4f}, Specificity: {pad_legume_specificity:.4f}, F1 Score: {pad_legume_f1:.4f}")
        # print(f"Fold {result['fold']} ({pad_data}) - Average: Precision: {pad_avg_precision:.4f}, Recall: {pad_avg_sensitivity:.4f}, Specificity: {pad_avg_specificity:.4f}, F1 Score: {pad_avg_f1:.4f}")

        eval_data.append({
            'split': pad_data,
            'fold': result['fold'],
            'precision': {
                'grass': grass_precision,
                'legume': legume_precision,
                'average': avg_precision,
                'grass (paddock)': pad_grass_precision,
                'legume (paddock)': pad_legume_precision,
                'average (paddock)': pad_avg_precision
            },
            'recall': {
                'grass': grass_recall,
                'legume': legume_recall,
                'average': avg_sensitivity,
                'grass (paddock)': pad_grass_recall,
                'legume (paddock)': pad_legume_recall,
                'average (paddock)': pad_avg_sensitivity
            },
            'specificity': {
                'grass': grass_specificity,
                'legume': legume_specificity,
                'average': avg_specificity,
                'grass (paddock)': pad_grass_specificity,
                'legume (paddock)': pad_legume_specificity,
                'average (paddock)': pad_avg_specificity
            },
            'f1': {
                'grass': grass_f1,
                'legume': legume_f1,
                'average': avg_f1,
                'grass (paddock)': pad_grass_f1,
                'legume (paddock)': pad_legume_f1,
                'average (paddock)': pad_avg_f1
            }
        })

rows = []

for result in eval_data:
    split = result.get('split', None)
    fold = result.get('fold', None)

    for cls_name in result['precision'].keys():
        rows.append({
            'Split': split,
            'Fold': fold,
            'Class': cls_name.capitalize(),
            'Precision': result['precision'][cls_name],
            'Recall': result['recall'][cls_name],
            'Specificity': result['specificity'][cls_name],
            'F1 Score': result['f1'][cls_name]
        })

eval_df = pd.DataFrame(rows)
eval_df = eval_df[['Split', 'Fold', 'Class', 'Precision', 'Recall', 'Specificity', 'F1 Score']]
eval_df.to_csv('./evaluation_patch50_summary.csv', index=False, float_format='%.4f')
print(eval_df)
# Out:
# Starting Fold 1
# Epoch 1/100 - Train Loss: 0.6652, Val Loss: 0.5937
# Epoch 2/100 - Train Loss: 0.6169, Val Loss: 0.5328
# Epoch 3/100 - Train Loss: 0.5349, Val Loss: 0.4842
# Epoch 4/100 - Train Loss: 0.4490, Val Loss: 0.4814
# Epoch 5/100 - Train Loss: 0.3792, Val Loss: 0.3594
# Epoch 6/100 - Train Loss: 0.3538, Val Loss: 0.3182
# Epoch 7/100 - Train Loss: 0.2863, Val Loss: 0.2779
# Epoch 8/100 - Train Loss: 0.2969, Val Loss: 0.2719
# Epoch 9/100 - Train Loss: 0.2766, Val Loss: 0.2615
# Epoch 10/100 - Train Loss: 0.2261, Val Loss: 0.2389
# Epoch 11/100 - Train Loss: 0.2442, Val Loss: 0.2054
# Epoch 12/100 - Train Loss: 0.2287, Val Loss: 0.2328
# Epoch 13/100 - Train Loss: 0.1963, Val Loss: 0.2070
# Epoch 14/100 - Train Loss: 0.2028, Val Loss: 0.2551
# Epoch 15/100 - Train Loss: 0.1783, Val Loss: 0.1939
# Epoch 16/100 - Train Loss: 0.1649, Val Loss: 0.1728
# Epoch 17/100 - Train Loss: 0.1673, Val Loss: 0.1604
# Epoch 18/100 - Train Loss: 0.1626, Val Loss: 0.1549
# Epoch 19/100 - Train Loss: 0.1795, Val Loss: 0.1520
# Epoch 20/100 - Train Loss: 0.1570, Val Loss: 0.1459
# Epoch 21/100 - Train Loss: 0.1374, Val Loss: 0.1608
# Epoch 22/100 - Train Loss: 0.2433, Val Loss: 0.2204
# Epoch 23/100 - Train Loss: 0.1401, Val Loss: 0.1779
# Epoch 24/100 - Train Loss: 0.1420, Val Loss: 0.2103
# Epoch 25/100 - Train Loss: 0.1618, Val Loss: 0.1464
# Epoch 26/100 - Train Loss: 0.1589, Val Loss: 0.1773
# Epoch 27/100 - Train Loss: 0.1298, Val Loss: 0.1375
# Epoch 28/100 - Train Loss: 0.1055, Val Loss: 0.1299
# Epoch 29/100 - Train Loss: 0.0993, Val Loss: 0.1298
# Epoch 30/100 - Train Loss: 0.1008, Val Loss: 0.1194
# Epoch 31/100 - Train Loss: 0.0990, Val Loss: 0.1187
# Epoch 32/100 - Train Loss: 0.0994, Val Loss: 0.1280
# Epoch 33/100 - Train Loss: 0.0940, Val Loss: 0.1200
# Epoch 34/100 - Train Loss: 0.0944, Val Loss: 0.1244
# Epoch 35/100 - Train Loss: 0.1066, Val Loss: 0.1133
# Epoch 36/100 - Train Loss: 0.1157, Val Loss: 0.1266
# Epoch 37/100 - Train Loss: 0.0906, Val Loss: 0.1139
# Epoch 38/100 - Train Loss: 0.0909, Val Loss: 0.1005
# Epoch 39/100 - Train Loss: 0.0918, Val Loss: 0.1075
# Epoch 42/100 - Train Loss: 0.0674, Val Loss: 0.1909
# Epoch 43/100 - Train Loss: 0.0724, Val Loss: 0.1898
# Epoch 44/100 - Train Loss: 0.0627, Val Loss: 0.1891
# Epoch 45/100 - Train Loss: 0.0763, Val Loss: 0.1919
# Epoch 46/100 - Train Loss: 0.0739, Val Loss: 0.1903
# Epoch 47/100 - Train Loss: 0.0853, Val Loss: 0.1901
# Epoch 48/100 - Train Loss: 0.0603, Val Loss: 0.1891
# Epoch 49/100 - Train Loss: 0.0655, Val Loss: 0.1897
# Epoch 50/100 - Train Loss: 0.0656, Val Loss: 0.1896
# Epoch 51/100 - Train Loss: 0.0758, Val Loss: 0.1886
# Epoch 52/100 - Train Loss: 0.0613, Val Loss: 0.1884
# Epoch 53/100 - Train Loss: 0.0699, Val Loss: 0.1891
# Epoch 54/100 - Train Loss: 0.0640, Val Loss: 0.1890
# Epoch 55/100 - Train Loss: 0.0725, Val Loss: 0.1884
# Epoch 56/100 - Train Loss: 0.0759, Val Loss: 0.1887
# Epoch 57/100 - Train Loss: 0.0663, Val Loss: 0.1889
# Epoch 58/100 - Train Loss: 0.0630, Val Loss: 0.1890
# Epoch 59/100 - Train Loss: 0.0789, Val Loss: 0.1893
# Epoch 60/100 - Train Loss: 0.0677, Val Loss: 0.1941
# Epoch 61/100 - Train Loss: 0.0750, Val Loss: 0.1894
# Epoch 62/100 - Train Loss: 0.0689, Val Loss: 0.1897
# Epoch 63/100 - Train Loss: 0.0710, Val Loss: 0.1906
# Epoch 64/100 - Train Loss: 0.0642, Val Loss: 0.1895
# Epoch 65/100 - Train Loss: 0.0724, Val Loss: 0.1892
# Epoch 66/100 - Train Loss: 0.0632, Val Loss: 0.1885
# Epoch 67/100 - Train Loss: 0.0640, Val Loss: 0.1905
# Epoch 68/100 - Train Loss: 0.0595, Val Loss: 0.1902
# Epoch 69/100 - Train Loss: 0.0861, Val Loss: 0.1893
# Early stopping triggered at epoch 70
# Fold 1:
# Confusion Matrix:
# [[61  1]
#  [ 9 40]]
# Fold 2:
# Confusion Matrix:
# [[60  2]
#  [11 38]]
# Fold 3:
# Confusion Matrix:
# [[60  2]
#  [15 34]]
# Fold 4:
# Confusion Matrix:
# [[60  2]
#  [15 34]]
# Fold 5:
# Confusion Matrix:
# [[60  2]
#  [13 36]]
# Starting Fold 1
# Epoch 1/100 - Train Loss: 0.6753, Val Loss: 0.6646
# Epoch 2/100 - Train Loss: 0.6645, Val Loss: 0.6367
# Epoch 3/100 - Train Loss: 0.6114, Val Loss: 0.5920
# Epoch 4/100 - Train Loss: 0.5577, Val Loss: 0.4895
# Epoch 5/100 - Train Loss: 0.4921, Val Loss: 0.4140
# Epoch 6/100 - Train Loss: 0.4107, Val Loss: 0.3188
# Epoch 7/100 - Train Loss: 0.3223, Val Loss: 0.2516
# Epoch 8/100 - Train Loss: 0.2849, Val Loss: 0.2951
# Epoch 9/100 - Train Loss: 0.2785, Val Loss: 0.2148
# Epoch 10/100 - Train Loss: 0.2122, Val Loss: 0.2048
# Epoch 11/100 - Train Loss: 0.2038, Val Loss: 0.1749
# Epoch 12/100 - Train Loss: 0.2254, Val Loss: 0.2488
# Epoch 13/100 - Train Loss: 0.1734, Val Loss: 0.2217
# Epoch 14/100 - Train Loss: 0.3529, Val Loss: 0.2787
# Epoch 15/100 - Train Loss: 0.1916, Val Loss: 0.2198
# Epoch 16/100 - Train Loss: 0.1613, Val Loss: 0.2300
# Epoch 17/100 - Train Loss: 0.1489, Val Loss: 0.1949
# Epoch 18/100 - Train Loss: 0.1825, Val Loss: 0.2042
# Epoch 19/100 - Train Loss: 0.1483, Val Loss: 0.1955
# Epoch 20/100 - Train Loss: 0.1348, Val Loss: 0.2166
# Epoch 21/100 - Train Loss: 0.1092, Val Loss: 0.1942
# Epoch 22/100 - Train Loss: 0.1179, Val Loss: 0.1788
# Epoch 23/100 - Train Loss: 0.1195, Val Loss: 0.1709
# Epoch 24/100 - Train Loss: 0.0952, Val Loss: 0.2027
# Epoch 25/100 - Train Loss: 0.0749, Val Loss: 0.1631
# Epoch 26/100 - Train Loss: 0.1073, Val Loss: 0.2126
# Epoch 27/100 - Train Loss: 0.0772, Val Loss: 0.2027
# Epoch 28/100 - Train Loss: 0.0990, Val Loss: 0.3134
# Epoch 29/100 - Train Loss: 0.1312, Val Loss: 0.1611
# Epoch 30/100 - Train Loss: 0.0696, Val Loss: 0.2193
# Epoch 31/100 - Train Loss: 0.0711, Val Loss: 0.1626
# Epoch 32/100 - Train Loss: 0.1463, Val Loss: 0.2922
# Epoch 33/100 - Train Loss: 0.0743, Val Loss: 0.1572
# Epoch 34/100 - Train Loss: 0.0677, Val Loss: 0.2593
# Epoch 35/100 - Train Loss: 0.0615, Val Loss: 0.1701
# Epoch 36/100 - Train Loss: 0.0478, Val Loss: 0.1759
# Epoch 37/100 - Train Loss: 0.0556, Val Loss: 0.1977
# Epoch 38/100 - Train Loss: 0.0449, Val Loss: 0.1808
# Epoch 39/100 - Train Loss: 0.0357, Val Loss: 0.2151
# Epoch 40/100 - Train Loss: 0.0432, Val Loss: 0.1843
# Epoch 41/100 - Train Loss: 0.0679, Val Loss: 0.1714
# Epoch 42/100 - Train Loss: 0.0369, Val Loss: 0.1701
# Epoch 43/100 - Train Loss: 0.0322, Val Loss: 0.1890
# Epoch 44/100 - Train Loss: 0.0324, Val Loss: 0.1924
# Epoch 45/100 - Train Loss: 0.0434, Val Loss: 0.1833
# Epoch 46/100 - Train Loss: 0.0469, Val Loss: 0.2466
# Epoch 47/100 - Train Loss: 0.0591, Val Loss: 0.2108
# Early stopping triggered at epoch 48
# Fold 1:
# Confusion Matrix:
# [[57  5]
#  [ 5 44]]
# Fold 2:
# Confusion Matrix:
# [[57  5]
#  [ 7 42]]
# Fold 3:
# Confusion Matrix:
# [[56  6]
#  [10 39]]
# Fold 4:
# Confusion Matrix:
# [[57  5]
#  [13 36]]
# Fold 5:
# Confusion Matrix:
# [[58  4]
#  [12 37]]
# Starting Fold 1
# Epoch 1/100 - Train Loss: 0.6600, Val Loss: 0.6407
# Epoch 2/100 - Train Loss: 0.6301, Val Loss: 0.5915
# Epoch 3/100 - Train Loss: 0.5297, Val Loss: 0.5194
# Epoch 19/100 - Train Loss: 0.1280, Val Loss: 0.1645
# Epoch 20/100 - Train Loss: 0.1139, Val Loss: 0.1595
# Epoch 21/100 - Train Loss: 0.1324, Val Loss: 0.1563
# Epoch 22/100 - Train Loss: 0.1327, Val Loss: 0.1638
# Epoch 23/100 - Train Loss: 0.1091, Val Loss: 0.1631
# Epoch 24/100 - Train Loss: 0.1032, Val Loss: 0.1543
# Epoch 25/100 - Train Loss: 0.1188, Val Loss: 0.1582
# Epoch 26/100 - Train Loss: 0.1002, Val Loss: 0.1505
# Epoch 27/100 - Train Loss: 0.1044, Val Loss: 0.1525
# Epoch 28/100 - Train Loss: 0.0995, Val Loss: 0.1448
# Epoch 29/100 - Train Loss: 0.1383, Val Loss: 0.1609
# Epoch 30/100 - Train Loss: 0.1334, Val Loss: 0.1512
# Epoch 31/100 - Train Loss: 0.1208, Val Loss: 0.1722
# Epoch 32/100 - Train Loss: 0.0987, Val Loss: 0.1597
# Epoch 33/100 - Train Loss: 0.0838, Val Loss: 0.1597
# Epoch 34/100 - Train Loss: 0.0876, Val Loss: 0.1617
# Epoch 35/100 - Train Loss: 0.0708, Val Loss: 0.1606
# Epoch 36/100 - Train Loss: 0.0689, Val Loss: 0.1587
# Epoch 37/100 - Train Loss: 0.0717, Val Loss: 0.1581
# Epoch 38/100 - Train Loss: 0.0709, Val Loss: 0.1630
# Epoch 39/100 - Train Loss: 0.0807, Val Loss: 0.1575
# Epoch 40/100 - Train Loss: 0.0778, Val Loss: 0.1658
# Epoch 41/100 - Train Loss: 0.0706, Val Loss: 0.1681
# Epoch 42/100 - Train Loss: 0.0703, Val Loss: 0.1652
# Early stopping triggered at epoch 43
# Fold 1:
# Confusion Matrix:
# [[62  4]
#  [ 6 39]]
# Fold 2:
# Confusion Matrix:
# [[61  5]
#  [ 5 40]]
# Fold 3:
# Confusion Matrix:
# [[59  7]
#  [ 9 36]]
# Fold 4:
# Confusion Matrix:
# [[63  3]
#  [ 7 38]]
# Fold 5:
# Confusion Matrix:
# [[61  5]
#  [ 5 40]]
#          Split  Fold              Class  Precision    Recall  Specificity  \
# 0   split_pad3     1              Grass   0.871429  0.983871     0.816327
# 1   split_pad3     1             Legume   0.975610  0.816327     0.983871
# 2   split_pad3     1            Average   0.923519  0.900099     0.900099
# 3   split_pad3     1    Grass (paddock)   0.718750  1.000000     0.640000
# 4   split_pad3     1   Legume (paddock)   1.000000  0.640000     1.000000
# ..         ...   ...                ...        ...       ...          ...
# 85  split_pad9     5             Legume   0.888889  0.888889     0.924242
# 86  split_pad9     5            Average   0.906566  0.906566     0.906566
# 87  split_pad9     5    Grass (paddock)   0.807692  0.913043     0.782609
# 88  split_pad9     5   Legume (paddock)   0.900000  0.782609     0.913043
# 89  split_pad9     5  Average (paddock)   0.853846  0.847826     0.847826
#
#     F1 Score
# 0   0.924242
# 1   0.888888
# 2   0.906565
# 3   0.836363
# 4   0.780487
# ..       ...
# 85  0.888888
# 86  0.906565
# 87  0.857142
# 88  0.837209
# 89  0.847176
#
# [90 rows x 7 columns]
