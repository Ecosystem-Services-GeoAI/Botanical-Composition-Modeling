# %%
import pandas as pd
import os
import openpyxl
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Define the folder containing the .xlsx files
folder_path = './pointDataTable'

# List to store DataFrames from each file
df_list = []

# Iterate over all files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.xlsx') and not filename.startswith("."):  # Only process .xlsx files
        file_path = os.path.join(folder_path, filename)
        # Read the .xlsx file into a DataFrame
        df = pd.read_excel(file_path)
        df['Source_File'] = filename
        print(filename)
        df_list.append(df)

# Concatenate all DataFrames in the list
merged_df = pd.concat(df_list, ignore_index=True)

# Save the merged DataFrame to a .csv file
# merged_df.to_csv('./all_dot_202409.csv', index=False)

# print("Data merged and saved to 'merged_output.csv'")
# Out:
# pad1_grass.xlsx
# pad2_grass.xlsx
# pad3_grass.xlsx
# pad3_Legume.xlsx
# pad4_grass.xlsx
# pad5_grass.xlsx
# pad5_Legume.xlsx
# pad6_grass.xlsx
# pad7_grass.xlsx
# pad8_grass.xlsx
# pad9_grass.xlsx
# pad9_Legume.xlsx
# soil.xlsx

# %%
red = merged_df.iloc[:,2]
green = merged_df.iloc[:,1]
blue = merged_df.iloc[:,0]
rd = merged_df.iloc[:,3]
nir = merged_df.iloc[:,4]
savi = ((nir-red)/(nir + red + 0.5)) * 1.5
merged_df['SAVI'] = savi

ndvi = (nir-red)/(nir+red)
merged_df['ndvi'] = ndvi

vari = (green - red)/(green + red - blue)
merged_df['vari'] = vari

exg = 2 * green - red - blue
merged_df['exg'] = exg

ndre = (nir-rd)/(nir+rd)
merged_df['ndre'] = ndre

merged_df.to_csv('./all_dot_202409.csv')

# %%
# Create a box plot
sns.boxplot(x='class', y='SAVI', data=merged_df)

# Show the plot
plt.show()

# %%
# data = pd.read_excel('./train/train_all.xlsx')
data =pd.read_csv("../all_data_two_date.csv")
data_filter_savi = data[data["SAVI"]>=0.9]
data_filter_savi
# Step 2: Prepare the features (X) and target (y)
# X = data.iloc[:,0:11]
# y = data['class']
summary_table = data.groupby('class').size().reset_index(name='count')
print(summary_table)

summary_table_2 = data_filter_savi.groupby('class').size().reset_index(name='count')
print(summary_table_2)
data_filter_savi.to_csv("../all_data_two_date_SAVI_filter_0.9.csv", index=False)

# %%
df_sep = pd.read_csv("../data/all_dot_202409.csv")
# Create a box plot
ax = sns.boxplot(x='class', y='SAVI', data=df_sep, palette="Set2")
ax.set_xlabel("Pixel Class")
# Show the plot
plt.show()
# Out:
# C:\Users\zhou.tang\AppData\Local\Temp\ipykernel_22208\3606898535.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='class', y='SAVI', data=df_sep, palette="Set2")

# %%
df_july = pd.read_csv("../data/Modeling_data_7-26-2024/all_data.csv")
# Create a box plot
ax = sns.boxplot(x='class', y='SAVI', data=df_july, palette="Set2")
ax.set_xlabel("Pixel Class")
# Show the plot
plt.show()
# Out:
# C:\Users\zhou.tang\AppData\Local\Temp\ipykernel_22208\2298601519.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='class', y='SAVI', data=df_july, palette="Set2")

# %%
# Define the folder containing the .xlsx files
folder_path = '../Modeling_data_7-26-2024/pointTable'

# List to store DataFrames from each file
df_list = []

# Iterate over all files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.csv') and not filename.startswith("."):  # Only process .xlsx files
        file_path = os.path.join(folder_path, filename)
        # Read the .xlsx file into a DataFrame
        df = pd.read_csv(file_path)
        df['Source_File'] = filename
        print(filename)
        df_list.append(df)

# Concatenate all DataFrames in the list
merged_df = pd.concat(df_list, ignore_index=True)
merged_df
# Save the merged DataFrame to a .csv file
merged_df.to_csv('./all_dot_202407.csv', index=False)

# print("Data merged and saved to 'merged_output.csv'")
# Out:
# pad1_grass_gps.csv
# pad2_grass_gps.csv
# pad3_grass_gps.csv
# pad3_legume_gps.csv
# pad4_grass_gps.csv
# pad5_grass_gps.csv
# pad5_legume_gps.csv
# pad6_grass_gps.csv
# pad7_grass_gps.csv
# pad8_grass_gps.csv
# pad9_grass_gps.csv
# pad9_legume_gps.csv
# smallplot_legume_gps.csv
# soil_gps.csv

# %%
# Define the folder containing the .xlsx files
folder_path = '../Modeling_data_09-22-2024/table_gps'

# List to store DataFrames from each file
df_list = []

# Iterate over all files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.csv') and not filename.startswith("."):  # Only process .xlsx files
        file_path = os.path.join(folder_path, filename)
        # Read the .xlsx file into a DataFrame
        df = pd.read_csv(file_path)
        df['Source_File'] = filename
        print(filename)
        df_list.append(df)

# Concatenate all DataFrames in the list
merged_df = pd.concat(df_list, ignore_index=True)
merged_df
# Save the merged DataFrame to a .csv file
merged_df.to_csv('../all_dot_202409_gps.csv', index=False)
# Out:
# pad1_grass_gps.csv
# pad2_grass_gps.csv
# pad3_grass_gps.csv
# pad3_Legume_gps.csv
# pad4_grass_gps.csv
# pad5_grass_gps.csv
# pad5_Legume_gps.csv
# pad6_grass_gps.csv
# pad7_grass_gps.csv
# pad8_grass_gps.csv
# pad9_grass_gps.csv
# pad9_Legume_gps.csv
# soil_gps.csv

# %%
#
file = "../all_dot_202407_gps.csv"
outfile = '../all_dot_202407_gps_vi.csv'
filter_file = '../all_dot_202407_gps_vi_savi_filter_0.9.csv'
merged_df =pd.read_csv(file)
red = merged_df.iloc[:,2]
green = merged_df.iloc[:,1]
blue = merged_df.iloc[:,0]
rd = merged_df.iloc[:,3]
nir = merged_df.iloc[:,4]
savi = ((nir-red)/(nir + red + 0.5)) * 1.5
merged_df['SAVI'] = savi

ndvi = (nir-red)/(nir+red)
merged_df['ndvi'] = ndvi

vari = (green - red)/(green + red - blue)
merged_df['vari'] = vari

exg = 2 * green - red - blue
merged_df['exg'] = exg

ndre = (nir-rd)/(nir+rd)
merged_df['ndre'] = ndre
merged_df.to_csv(outfile)
fitler_df = merged_df[merged_df['SAVI'] >=0.9]
fitler_df.to_csv(filter_file,index=False)
